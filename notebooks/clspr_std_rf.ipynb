# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

from pathlib import Path
import os
import sys
from datetime import datetime, date

from random import sample
import random

import time

# %%
result = Path('result/')
report = Path('report/')
instances = Path('instances/csifa')

# %%
file_name = sys.argv[1]
#tam_part = int(sys.argv[2]) # Tamanho das partições
#num_fix = int(sys.argv[3]) # número de variáveis que serão fixadas

# %%
def read_instance(file_name):
	
	arq = open(file_name)
	
	N = int(arq.readline())
	
	PR  = [0]*N
	PP  = [0]*N

	FR = [float(arq.readline())]*N
	FP = [float(arq.readline())]*N

	HR = [float(arq.readline())]*N
	HP = [float(arq.readline())]*N

	D = [int(i) for i in arq.readline().split()]
	
	R = [int(i) for i in arq.readline().split()]

	C = float(arq.readline().rstrip('\n'))
	
	return N, PP, PR, FP, FR, HR, HP, D, R, C

# %%
def run_time(start_time=None):

	if not start_time:
		start_time = datetime.now()
		return start_time
	
	elif start_time:
		temp_sec = (datetime.now() - start_time).total_seconds()
		return temp_sec

# %%
def gera_particoes(N, tam_part=5, num_part_fix=2, seme=5, ind_gen=1):
	
	tam_jan = tam_part - num_part_fix
	subset = []
	 
	if ind_gen == 1:
		for i in range(0, N, tam_jan):
			if i + tam_part > N:
				subset.append([k for k in range(i,N)])
			else:
				subset.append([k for k in range(i,i+tam_part)])
	else:
		random.seed(seme)
		list_per = [k  for k in range(N)]
	
		while True:		 
			sub_conj = []
			 
			if len(list_per) >= tam_part:
				sub_conj = sample(list_per, tam_part)
			else:
				sub_conj = list_per[:]
			subset.append(sub_conj)

			for i in sub_conj:
				list_per.remove(i)
			
			if len(list_per)==0:
				break
	
	return subset

# %%
MAX_CPU_TIME = 3600.0
EPSILON = 1.e-6

def relax_and_fix(N, PP, PR, FP, FR, HR, HP, D, R, SD, SR, C, parts, yp_sol, yr_sol):

	objval = 0.0

	try:

		# Create a new model
		model = gp.Model("CLSR")

		# Create variables
		xp = model.addVars(list(range(N)), vtype=GRB.CONTINUOUS, name="xp")
		yp = model.addVars(list(range(N)), vtype=GRB.BINARY, name="yp")
		sp = model.addVars(list(range(N)), vtype=GRB.CONTINUOUS, name="sp")
		xr = model.addVars(list(range(N)), vtype=GRB.CONTINUOUS, name="xr")
		yr = model.addVars(list(range(N)), vtype=GRB.BINARY, name="yr")
		sr = model.addVars(list(range(N)), vtype=GRB.CONTINUOUS, name="sr")
		
		for i in range(N):
			if i > max(parts) :
				yp[i].VType = gp.GRB.CONTINUOUS
				yp[i].lb    = 0.0
				yp[i].ub    = 1.0
				yr[i].VType = gp.GRB.CONTINUOUS
				yr[i].lb    = 0.0
				yr[i].ub    = 1.0
			elif i in parts:
				yp[i].lb = 0.0
				yp[i].ub = 1.0
				yr[i].lb = 0.0
				yr[i].ub = 1.0
			else:
				yp[i].lb = yp_sol[i]
				yp[i].ub = yp_sol[i]
				yr[i].lb = yr_sol[i]
				yr[i].ub = yr_sol[i]
		
		model.update()

		# Set objective
		model.setObjective(gp.quicksum(PP[i]*xp[i]+sp[i]*HP[i] + xr[i]*PR[i] + sr[i]*HR[i] + yp[i]*FP[i] + yr[i]*FR[i] for i in range(N)), sense=GRB.MINIMIZE)

		# Add constraints
		model.addConstr(xp[0] + xr[0] - sp[0] == D[0])

		model.addConstrs(sp[i-1] + xp[i] + xr[i] - sp[i] == D[i] for i in range(N) if i > 0 )
		
		model.addConstr(R[0] - xr[0] - sr[0] == 0)
		
		model.addConstrs(sr[i-1] + R[i] - xr[i] - sr[i] == 0 for i in range(N) if i > 0)
		
		model.addConstrs(xp[i] - yp[i]*min(C,SD[i][N-1]) <= 0 for i in range(N))
		
		model.addConstrs(xr[i] - yr[i]*min(SR[0][i], SD[i][N-1]) <= 0 for i in range(N))
		
		model.addConstrs(xp[i] + xr[i] <= C for i in range(N))
		
		# Parameters 
		model.setParam(GRB.Param.TimeLimit, MAX_CPU_TIME)
		model.setParam(GRB.Param.MIPGap, EPSILON)
		model.setParam(GRB.Param.Threads,1)
		#model.setParam(GRB.Param.Cuts,-1)
		#model.setParam(GRB.Param.Presolve,-1)

		# Optimize model
		model.optimize()

		objval = model.ObjVal

		yp_val = [0]*N
		yr_val = [0]*N

		yp_val = [yp[i].X for i in range(N)]
		yr_val = [yr[i].X for i in range(N)]

	except gp.GurobiError as e:
		print('Error code ' + str(e.errno) + ': ' + str(e))

	#except AttributeError:
	#	print('Encountered an attribute error')

	return objval, yp_val, yr_val

# %%
def main(file_name):

	solution = 0.0

	tam_part = 5
	num_fix = 2
	
	N, PP, PR, FP, FR, HR, HP, D, R, C = read_instance(os.path.join(instances,file_name))

	SD = (np.zeros((N,N))).tolist()
	SR = (np.zeros((N,N))).tolist()
	for  i in range(N):
		SD[i][i] = D[i]
		SR[i][i] = R[i]
		for j in range(i+1,N):
			SD[i][j] = SD[i][j-1] + D[j]
			SR[i][j] = SR[i][j-1] + R[j]

	subset = gera_particoes(N, tam_part, num_fix)

	yp_sol = [0]*N
	yr_sol = [0]*N

	start_time = time.time()
	
	for s in subset:
		solution, yp_sol, yr_sol = relax_and_fix(N, PP, PR, FP, FR, HR, HP, D, R, SD, SR, C, s, yp_sol, yr_sol)
		 
	run_time = time.time() - start_time
	
	arquivo = open(os.path.join(result,'clsr_std_rf.txt'),'a')
	arquivo.write(file_name+';'+str(round(solution,2))+';'+str(round(run_time,2))+'\n')

	arquivo.close()

# %%
if __name__== "__main__" :

	file_name = f"c52_1.txt"

	main(file_name)
# Out:
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xddc53cb8
# Variable types: 302 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 99 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 161 rows, 213 columns, 477 nonzeros
# Variable types: 204 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 6579.1075856
#
# Root relaxation: objective 5.376769e+03, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5376.76926    0    4 6579.10759 5376.76926  18.3%     -    0s
# H    0     0                    5760.1025908 5376.76926  6.65%     -    0s
# H    0     0                    5698.8825579 5376.76926  5.65%     -    0s
# H    0     0                    5668.4359241 5376.76926  5.15%     -    0s
#      0     0 5532.81539    0    4 5668.43592 5532.81539  2.39%     -    0s
# H    0     0                    5572.0123475 5532.81539  0.70%     -    0s
#      0     0 5560.21336    0    4 5572.01235 5560.21336  0.21%     -    0s
#      0     0     cutoff    0      5572.01235 5572.01235  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 3
#   MIR: 1
#   Flow cover: 8
#
# Explored 1 nodes (164 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 5572.01 5668.44 5698.88 6579.11
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 5.572012347534e+03, best bound 5.572012347534e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x4af31484
# Variable types: 296 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 105 rows and 108 columns
# Presolve time: 0.00s
# Presolved: 155 rows, 204 columns, 457 nonzeros
# Variable types: 194 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 6743.7279759
#
# Root relaxation: objective 5.488073e+03, 144 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5488.07333    0    6 6743.72798 5488.07333  18.6%     -    0s
# H    0     0                    5999.2391728 5488.07333  8.52%     -    0s
# H    0     0                    5814.6041664 5488.07333  5.62%     -    0s
#      0     0 5689.77033    0    9 5814.60417 5689.77033  2.15%     -    0s
# H    0     0                    5770.9207687 5689.77033  1.41%     -    0s
#      0     0 5703.90193    0    6 5770.92077 5703.90193  1.16%     -    0s
#      0     0 5708.19456    0    4 5770.92077 5708.19456  1.09%     -    0s
#      0     0 5716.74938    0    5 5770.92077 5716.74938  0.94%     -    0s
#      0     0 5716.74938    0    5 5770.92077 5716.74938  0.94%     -    0s
#      0     0 5724.41236    0    7 5770.92077 5724.41236  0.81%     -    0s
# H    0     0                    5727.7493401 5724.41236  0.06%     -    0s
#      0     0     cutoff    0      5727.74934 5727.74934  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 1
#   MIR: 2
#   Flow cover: 7
#   Flow path: 2
#
# Explored 1 nodes (183 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 5727.75 5770.92 5814.6 ... 6743.73
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 5.727749340124e+03, best bound 5.727749340124e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x7870e997
# Variable types: 290 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 110 rows and 115 columns
# Presolve time: 0.00s
# Presolved: 150 rows, 197 columns, 438 nonzeros
# Variable types: 187 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 6826.6104999
#
# Root relaxation: objective 5.640552e+03, 142 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5640.55238    0    8 6826.61050 5640.55238  17.4%     -    0s
# H    0     0                    6669.3649151 5640.55238  15.4%     -    0s
# H    0     0                    6205.4475106 5640.55238  9.10%     -    0s
#      0     0 5877.83272    0    8 6205.44751 5877.83272  5.28%     -    0s
# H    0     0                    6088.4475106 5877.83272  3.46%     -    0s
#      0     0 5881.82613    0    8 6088.44751 5881.82613  3.39%     -    0s
#      0     0 5913.64331    0    7 6088.44751 5913.64331  2.87%     -    0s
#      0     0 5914.89673    0    7 6088.44751 5914.89673  2.85%     -    0s
#      0     0 5914.91889    0    7 6088.44751 5914.91889  2.85%     -    0s
#      0     0 5932.31061    0    8 6088.44751 5932.31061  2.56%     -    0s
#      0     0 5941.23433    0    9 6088.44751 5941.23433  2.42%     -    0s
#      0     0 5941.81407    0   10 6088.44751 5941.81407  2.41%     -    0s
#      0     0 5952.39274    0    9 6088.44751 5952.39274  2.23%     -    0s
#      0     0 5952.75610    0    6 6088.44751 5952.75610  2.23%     -    0s
#      0     0 5952.77319    0   10 6088.44751 5952.77319  2.23%     -    0s
#      0     0 5954.73680    0    7 6088.44751 5954.73680  2.20%     -    0s
# H    0     0                    5981.4475106 5954.73680  0.45%     -    0s
#      0     0 5954.92588    0    7 5981.44751 5954.92588  0.44%     -    0s
#      0     0 5955.33561    0    7 5981.44751 5955.33561  0.44%     -    0s
#      0     0 5955.88109    0    7 5981.44751 5955.88109  0.43%     -    0s
#      0     0 5955.88109    0    7 5981.44751 5955.88109  0.43%     -    0s
#      0     2 5956.71803    0    7 5981.44751 5956.71803  0.41%     -    0s
#
# Cutting planes:
#   MIR: 11
#   Flow cover: 11
#
# Explored 19 nodes (329 simplex iterations) in 0.15 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 5981.45 6088.45 6205.45 ... 6826.61
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 5.981447510593e+03, best bound 5.981447510593e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x81e98fa8
# Variable types: 284 continuous, 28 integer (28 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 118 rows and 125 columns
# Presolve time: 0.00s
# Presolved: 142 rows, 187 columns, 413 nonzeros
# Variable types: 177 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 6746.0967864
#
# Root relaxation: objective 5.928335e+03, 135 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5928.33503    0    7 6746.09679 5928.33503  12.1%     -    0s
# H    0     0                    6226.3538797 5928.33503  4.79%     -    0s
#      0     0 6118.51443    0    6 6226.35388 6118.51443  1.73%     -    0s
# H    0     0                    6206.7960535 6118.51443  1.42%     -    0s
#      0     0 6162.41753    0    3 6206.79605 6162.41753  0.71%     -    0s
#      0     0 6171.03366    0    6 6206.79605 6171.03366  0.58%     -    0s
#      0     0 6176.58771    0    6 6206.79605 6176.58771  0.49%     -    0s
# H    0     0                    6196.3538797 6176.58771  0.32%     -    0s
#      0     0 6178.61748    0    7 6196.35388 6178.61748  0.29%     -    0s
#      0     0 6181.39105    0    5 6196.35388 6181.39105  0.24%     -    0s
#      0     0 6181.57312    0    3 6196.35388 6181.57312  0.24%     -    0s
#      0     0 6182.15963    0    6 6196.35388 6182.15963  0.23%     -    0s
#      0     0 6183.19348    0    9 6196.35388 6183.19348  0.21%     -    0s
#      0     0 6184.31957    0    7 6196.35388 6184.31957  0.19%     -    0s
#      0     0 6184.95079    0    5 6196.35388 6184.95079  0.18%     -    0s
#      0     0 6187.00114    0    5 6196.35388 6187.00114  0.15%     -    0s
#      0     0 6187.16438    0    5 6196.35388 6187.16438  0.15%     -    0s
#      0     0 6187.25379    0    5 6196.35388 6187.25379  0.15%     -    0s
#      0     0 6188.20152    0    5 6196.35388 6188.20152  0.13%     -    0s
#      0     0 6188.20152    0    5 6196.35388 6188.20152  0.13%     -    0s
#      0     2 6192.16815    0    5 6196.35388 6192.16815  0.07%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 1
#   MIR: 4
#   Flow cover: 8
#   Flow path: 1
#
# Explored 5 nodes (214 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 6196.35 6206.8 6226.35 6746.1
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.196353879682e+03, best bound 6.196353879682e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x2429fbfa
# Variable types: 278 continuous, 34 integer (34 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 125 rows and 133 columns
# Presolve time: 0.00s
# Presolved: 135 rows, 179 columns, 393 nonzeros
# Variable types: 169 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 7025.8755824
#
# Root relaxation: objective 6.182116e+03, 125 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6182.11631    0    7 7025.87558 6182.11631  12.0%     -    0s
# H    0     0                    6675.6296991 6182.11631  7.39%     -    0s
#      0     0 6453.93007    0    6 6675.62970 6453.93007  3.32%     -    0s
# H    0     0                    6576.0730609 6453.93007  1.86%     -    0s
#      0     0 6469.02733    0    7 6576.07306 6469.02733  1.63%     -    0s
# H    0     0                    6481.4819915 6469.02733  0.19%     -    0s
#      0     0 6476.26720    0    4 6481.48199 6476.26720  0.08%     -    0s
#      0     0     cutoff    0      6481.48199 6481.48199  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#   Implied bound: 1
#   MIR: 3
#   Flow cover: 13
#
# Explored 1 nodes (162 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 6481.48 6576.07 6675.63 7025.88
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.481481991524e+03, best bound 6.481481991524e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x8791d6ad
# Variable types: 272 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 132 rows and 141 columns
# Presolve time: 0.00s
# Presolved: 128 rows, 171 columns, 373 nonzeros
# Variable types: 161 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 7290.7839259
#
# Root relaxation: objective 6.451508e+03, 116 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6451.50845    0    7 7290.78393 6451.50845  11.5%     -    0s
# H    0     0                    6912.3974853 6451.50845  6.67%     -    0s
#      0     0 6711.91034    0    7 6912.39749 6711.91034  2.90%     -    0s
# H    0     0                    6780.2462915 6711.91034  1.01%     -    0s
#      0     0 6743.05522    0    5 6780.24629 6743.05522  0.55%     -    0s
#      0     0 6743.82886    0    4 6780.24629 6743.82886  0.54%     -    0s
#      0     0 6745.70937    0    7 6780.24629 6745.70937  0.51%     -    0s
#      0     0 6747.42909    0    6 6780.24629 6747.42909  0.48%     -    0s
#      0     0 6747.51491    0    6 6780.24629 6747.51491  0.48%     -    0s
#      0     0 6748.10532    0    7 6780.24629 6748.10532  0.47%     -    0s
#      0     0 6752.99134    0    5 6780.24629 6752.99134  0.40%     -    0s
# H    0     0                    6768.4604647 6752.99134  0.23%     -    0s
#      0     0 6763.40956    0    4 6768.46046 6763.40956  0.07%     -    0s
#      0     0     cutoff    0      6768.46046 6768.46046  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 1
#   MIR: 3
#   StrongCG: 1
#   Flow cover: 6
#   Relax-and-lift: 1
#
# Explored 1 nodes (172 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 6768.46 6780.25 6912.4 7290.78
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.768460464687e+03, best bound 6.768460464687e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x36cbf1e2
# Variable types: 266 continuous, 46 integer (46 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 140 rows and 150 columns
# Presolve time: 0.00s
# Presolved: 120 rows, 162 columns, 350 nonzeros
# Variable types: 152 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 7395.9149071
#
# Root relaxation: objective 6.774679e+03, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6774.67881    0    6 7395.91491 6774.67881  8.40%     -    0s
# H    0     0                    7218.7149071 6774.67881  6.15%     -    0s
# H    0     0                    7134.1698920 6774.67881  5.04%     -    0s
#      0     0 6965.77591    0    6 7134.16989 6965.77591  2.36%     -    0s
#      0     0 7008.60559    0    6 7134.16989 7008.60559  1.76%     -    0s
# H    0     0                    7048.2803307 7008.60559  0.56%     -    0s
#      0     0 7014.28373    0    4 7048.28033 7014.28373  0.48%     -    0s
#      0     0 7017.02743    0    6 7048.28033 7017.02743  0.44%     -    0s
#      0     0 7020.72802    0    6 7048.28033 7020.72802  0.39%     -    0s
#      0     0 7021.47695    0    5 7048.28033 7021.47695  0.38%     -    0s
#      0     0 7026.57204    0    7 7048.28033 7026.57204  0.31%     -    0s
#      0     0 7026.74535    0    7 7048.28033 7026.74535  0.31%     -    0s
#      0     0 7030.27877    0    5 7048.28033 7030.27877  0.26%     -    0s
#      0     0 7033.83677    0    6 7048.28033 7033.83677  0.20%     -    0s
#      0     0 7033.89120    0    6 7048.28033 7033.89120  0.20%     -    0s
#      0     0 7039.68306    0    7 7048.28033 7039.68306  0.12%     -    0s
#      0     0 7041.69811    0    4 7048.28033 7041.69811  0.09%     -    0s
#      0     0 7044.76021    0    4 7048.28033 7044.76021  0.05%     -    0s
#      0     0 7046.34482    0    4 7048.28033 7046.34482  0.03%     -    0s
#      0     0 7047.20021    0    4 7048.28033 7047.20021  0.02%     -    0s
#      0     0 7047.66597    0    4 7048.28033 7047.66597  0.01%     -    0s
#      0     0 7047.73981    0    4 7048.28033 7047.73981  0.01%     -    0s
#      0     0 7047.73981    0    4 7048.28033 7047.73981  0.01%     -    0s
#      0     0     cutoff    0      7048.28033 7048.28033  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 7
#   StrongCG: 1
#   Flow cover: 5
#
# Explored 1 nodes (176 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 7048.28 7134.17 7218.71 7395.91
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.048280330748e+03, best bound 7.048280330748e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x5ffbab3a
# Variable types: 260 continuous, 52 integer (52 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 147 rows and 158 columns
# Presolve time: 0.00s
# Presolved: 113 rows, 154 columns, 330 nonzeros
# Variable types: 144 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 7886.8187528
#
# Root relaxation: objective 7.041104e+03, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7041.10447    0    6 7886.81875 7041.10447  10.7%     -    0s
# H    0     0                    7701.8187528 7041.10447  8.58%     -    0s
#      0     0 7271.70024    0    5 7701.81875 7271.70024  5.58%     -    0s
# H    0     0                    7439.2187528 7271.70024  2.25%     -    0s
#      0     0 7297.83546    0    4 7439.21875 7297.83546  1.90%     -    0s
#      0     0 7313.75676    0    5 7439.21875 7313.75676  1.69%     -    0s
#      0     0 7315.62928    0    6 7439.21875 7315.62928  1.66%     -    0s
#      0     0 7316.90948    0    7 7439.21875 7316.90948  1.64%     -    0s
#      0     0 7321.94556    0    6 7439.21875 7321.94556  1.58%     -    0s
# H    0     0                    7340.5549103 7321.94556  0.25%     -    0s
#      0     0 7326.54618    0    8 7340.55491 7326.54618  0.19%     -    0s
#      0     0 7330.57857    0    6 7340.55491 7330.57857  0.14%     -    0s
#      0     0 7331.08617    0    6 7340.55491 7331.08617  0.13%     -    0s
#      0     0 7331.40109    0    6 7340.55491 7331.40109  0.12%     -    0s
#      0     0 7331.40109    0    6 7340.55491 7331.40109  0.12%     -    0s
#      0     2 7331.79707    0    6 7340.55491 7331.79707  0.12%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 2
#   Flow cover: 11
#
# Explored 5 nodes (152 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 7340.55 7439.22 7701.82 7886.82
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.340554910282e+03, best bound 7.340549219322e+03, gap 0.0001%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xe8289442
# Variable types: 254 continuous, 58 integer (58 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 154 rows and 166 columns
# Presolve time: 0.00s
# Presolved: 106 rows, 146 columns, 310 nonzeros
# Variable types: 136 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 8184.5063357
#
# Root relaxation: objective 7.335144e+03, 96 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7335.14443    0    7 8184.50634 7335.14443  10.4%     -    0s
#      0     0 7580.41349    0    6 8184.50634 7580.41349  7.38%     -    0s
# H    0     0                    7587.8166514 7580.41349  0.10%     -    0s
#      0     0     cutoff    0      7587.81665 7587.81665  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   MIR: 8
#   Flow cover: 9
#
# Explored 1 nodes (118 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 7587.82 8184.51
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.587816651418e+03, best bound 7.587816651418e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xbdd851de
# Variable types: 248 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 162 rows and 175 columns
# Presolve time: 0.00s
# Presolved: 98 rows, 137 columns, 287 nonzeros
# Variable types: 127 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 8295.3015984
#
# Root relaxation: objective 7.652444e+03, 88 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7652.44446    0    6 8295.30160 7652.44446  7.75%     -    0s
# H    0     0                    8054.9015984 7652.44446  5.00%     -    0s
#      0     0 7827.05032    0    6 8054.90160 7827.05032  2.83%     -    0s
#      0     0 7828.08929    0    6 8054.90160 7828.08929  2.82%     -    0s
#      0     0 7828.10532    0    6 8054.90160 7828.10532  2.82%     -    0s
#      0     0 7842.14434    0    5 8054.90160 7842.14434  2.64%     -    0s
# H    0     0                    7901.2544055 7842.14434  0.75%     -    0s
#      0     0 7876.12434    0    7 7901.25441 7876.12434  0.32%     -    0s
#      0     0 7896.18675    0    8 7901.25441 7896.18675  0.06%     -    0s
#      0     0 7900.55541    0    3 7901.25441 7900.55541  0.01%     -    0s
#      0     0     cutoff    0      7901.25441 7901.25441  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 7
#   StrongCG: 1
#   Flow cover: 15
#
# Explored 1 nodes (143 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 7901.25 8054.9 8295.3
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.901254405489e+03, best bound 7.901254405489e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xad3b1527
# Variable types: 242 continuous, 70 integer (70 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 169 rows and 183 columns
# Presolve time: 0.00s
# Presolved: 91 rows, 129 columns, 267 nonzeros
# Variable types: 119 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 8744.5715088
#
# Root relaxation: objective 7.934191e+03, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7934.19056    0    6 8744.57151 7934.19056  9.27%     -    0s
# H    0     0                    8561.5715088 7934.19056  7.33%     -    0s
# H    0     0                    8347.5317711 7934.19056  4.95%     -    0s
#      0     0 8121.22533    0    5 8347.53177 8121.22533  2.71%     -    0s
#      0     0 8166.96235    0    7 8347.53177 8166.96235  2.16%     -    0s
# H    0     0                    8215.4798095 8166.96235  0.59%     -    0s
#      0     0 8172.46412    0    7 8215.47981 8172.46412  0.52%     -    0s
#      0     0 8176.11053    0    4 8215.47981 8176.11053  0.48%     -    0s
#      0     0 8183.36217    0    6 8215.47981 8183.36217  0.39%     -    0s
#      0     0 8184.03646    0    6 8215.47981 8184.03646  0.38%     -    0s
#      0     0 8185.32639    0    5 8215.47981 8185.32639  0.37%     -    0s
# H    0     0                    8194.1806225 8185.32639  0.11%     -    0s
#      0     0     cutoff    0      8194.18062 8194.18062  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 3
#   Flow cover: 7
#   Flow path: 3
#
# Explored 1 nodes (121 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 8194.18 8215.48 8347.53 ... 8744.57
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.194180622524e+03, best bound 8.194180622524e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x6b447252
# Variable types: 236 continuous, 76 integer (76 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 176 rows and 191 columns
# Presolve time: 0.00s
# Presolved: 84 rows, 121 columns, 247 nonzeros
# Variable types: 111 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 8838.6565430
#
# Root relaxation: objective 8.186342e+03, 73 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8186.34196    0    5 8838.65654 8186.34196  7.38%     -    0s
# H    0     0                    8708.9610033 8186.34196  6.00%     -    0s
# H    0     0                    8487.6053218 8186.34196  3.55%     -    0s
#      0     0 8401.66246    0    4 8487.60532 8401.66246  1.01%     -    0s
#      0     0 8416.86027    0    5 8487.60532 8416.86027  0.83%     -    0s
#      0     0 8432.57253    0    6 8487.60532 8432.57253  0.65%     -    0s
#      0     0 8432.77533    0    6 8487.60532 8432.77533  0.65%     -    0s
#      0     0 8435.94298    0    6 8487.60532 8435.94298  0.61%     -    0s
#      0     0 8440.43171    0    6 8487.60532 8440.43171  0.56%     -    0s
#      0     0 8440.88731    0    6 8487.60532 8440.88731  0.55%     -    0s
#      0     0 8441.51330    0    6 8487.60532 8441.51330  0.54%     -    0s
#      0     0 8441.76827    0    6 8487.60532 8441.76827  0.54%     -    0s
# H    0     0                    8461.8053218 8441.76827  0.24%     -    0s
#      0     0 8443.91799    0    5 8461.80532 8443.91799  0.21%     -    0s
#      0     0 8447.07252    0    6 8461.80532 8447.07252  0.17%     -    0s
#      0     0 8451.68853    0    5 8461.80532 8451.68853  0.12%     -    0s
#      0     0 8453.77680    0    5 8461.80532 8453.77680  0.09%     -    0s
#      0     0 8453.77680    0    5 8461.80532 8453.77680  0.09%     -    0s
#      0     2 8458.31120    0    5 8461.80532 8458.31120  0.04%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 5
#   Flow cover: 4
#   Flow path: 2
#
# Explored 3 nodes (130 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 8461.81 8487.61 8708.96 8838.66
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.461805321843e+03, best bound 8.461805321843e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x24c6ad2f
# Variable types: 230 continuous, 82 integer (82 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 184 rows and 200 columns
# Presolve time: 0.00s
# Presolved: 76 rows, 112 columns, 224 nonzeros
# Variable types: 102 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 8960.1950246
#
# Root relaxation: objective 8.543528e+03, 62 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8543.52836    0    5 8960.19502 8543.52836  4.65%     -    0s
# H    0     0                    8859.9493483 8543.52836  3.57%     -    0s
#      0     0 8722.34555    0    2 8859.94935 8722.34555  1.55%     -    0s
# H    0     0                    8775.9493483 8722.34555  0.61%     -    0s
#      0     0 8750.07679    0    7 8775.94935 8750.07679  0.29%     -    0s
#      0     0 8775.31680    0    2 8775.94935 8775.31680  0.01%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 3
#   Flow cover: 10
#
# Explored 1 nodes (93 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 8775.95 8859.95 8960.2
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.775949348344e+03, best bound 8.775949348344e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x84d4d6bc
# Variable types: 224 continuous, 88 integer (88 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 192 rows and 209 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 103 columns, 202 nonzeros
# Variable types: 93 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 9405.8519514
#
# Root relaxation: objective 8.824900e+03, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8824.89957    0    6 9405.85195 8824.89957  6.18%     -    0s
# H    0     0                    9142.4338441 8824.89957  3.47%     -    0s
#      0     0 9018.29810    0    6 9142.43384 9018.29810  1.36%     -    0s
#      0     0 9061.03399    0    8 9142.43384 9061.03399  0.89%     -    0s
#      0     0 9063.60251    0    8 9142.43384 9063.60251  0.86%     -    0s
#      0     0 9071.04325    0    8 9142.43384 9071.04325  0.78%     -    0s
#      0     0 9071.18239    0    8 9142.43384 9071.18239  0.78%     -    0s
#      0     0 9071.61415    0    8 9142.43384 9071.61415  0.77%     -    0s
#      0     0 9073.42930    0    9 9142.43384 9073.42930  0.75%     -    0s
#      0     0 9076.60781    0    9 9142.43384 9076.60781  0.72%     -    0s
#      0     0 9076.69477    0    9 9142.43384 9076.69477  0.72%     -    0s
#      0     0 9080.35755    0    8 9142.43384 9080.35755  0.68%     -    0s
#      0     0 9081.69447    0    9 9142.43384 9081.69447  0.66%     -    0s
#      0     0 9083.65228    0    8 9142.43384 9083.65228  0.64%     -    0s
#      0     0 9083.89945    0    9 9142.43384 9083.89945  0.64%     -    0s
#      0     0 9084.52788    0    8 9142.43384 9084.52788  0.63%     -    0s
# H    0     0                    9114.5908497 9084.52788  0.33%     -    0s
#      0     0 9087.14433    0    7 9114.59085 9087.14433  0.30%     -    0s
#      0     0 9087.41366    0    7 9114.59085 9087.41366  0.30%     -    0s
#      0     0 9088.20672    0    7 9114.59085 9088.20672  0.29%     -    0s
#      0     0 9090.49296    0    7 9114.59085 9090.49296  0.26%     -    0s
#      0     0 9091.51776    0    7 9114.59085 9091.51776  0.25%     -    0s
#      0     0 9091.52193    0    6 9114.59085 9091.52193  0.25%     -    0s
#      0     0 9091.58606    0    7 9114.59085 9091.58606  0.25%     -    0s
#      0     0 9092.24667    0    6 9114.59085 9092.24667  0.25%     -    0s
#      0     0 9093.01693    0    7 9114.59085 9093.01693  0.24%     -    0s
#      0     0 9093.37695    0    8 9114.59085 9093.37695  0.23%     -    0s
#      0     2 9093.71692    0    8 9114.59085 9093.71692  0.23%     -    0s
# H    8     2                    9108.4338441 9099.26281  0.10%   4.9    0s
#
# Cutting planes:
#   MIR: 8
#   Flow cover: 8
#
# Explored 21 nodes (247 simplex iterations) in 0.15 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 9108.43 9114.59 9142.43 9405.85
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.108433844075e+03, best bound 9.108433844075e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x871d822c
# Variable types: 218 continuous, 94 integer (94 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 199 rows and 217 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 95 columns, 182 nonzeros
# Variable types: 85 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 10050.017185
#
# Root relaxation: objective 9.101743e+03, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9101.74287    0    7 10050.0172 9101.74287  9.44%     -    0s
# H    0     0                    9860.0762016 9101.74287  7.69%     -    0s
# H    0     0                    9468.8949854 9101.74287  3.88%     -    0s
#      0     0 9346.24462    0    7 9468.89499 9346.24462  1.30%     -    0s
#      0     0 9349.06627    0    7 9468.89499 9349.06627  1.27%     -    0s
#      0     0 9376.19808    0    7 9468.89499 9376.19808  0.98%     -    0s
#      0     0 9378.86493    0    8 9468.89499 9378.86493  0.95%     -    0s
#      0     0 9380.10427    0    6 9468.89499 9380.10427  0.94%     -    0s
#      0     0 9380.14976    0    6 9468.89499 9380.14976  0.94%     -    0s
#      0     0 9385.46922    0    4 9468.89499 9385.46922  0.88%     -    0s
# H    0     0                    9421.8949854 9385.46922  0.39%     -    0s
#      0     0 9392.98623    0    8 9421.89499 9392.98623  0.31%     -    0s
#      0     0 9393.07916    0    8 9421.89499 9393.07916  0.31%     -    0s
#      0     0 9402.01001    0    6 9421.89499 9402.01001  0.21%     -    0s
#      0     0 9406.42219    0    9 9421.89499 9406.42219  0.16%     -    0s
#      0     0 9406.65088    0    8 9421.89499 9406.65088  0.16%     -    0s
#      0     0 9407.69719    0    8 9421.89499 9407.69719  0.15%     -    0s
#      0     0 9407.69719    0    8 9421.89499 9407.69719  0.15%     -    0s
#      0     2 9413.39408    0    8 9421.89499 9413.39408  0.09%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   Flow cover: 10
#   Flow path: 2
#
# Explored 5 nodes (132 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 9421.89 9468.89 9860.08 10050
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.421894985353e+03, best bound 9.421894985353e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x28602b0d
# Variable types: 212 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 204 rows and 222 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 90 columns, 167 nonzeros
# Variable types: 80 continuous, 10 integer (10 binary)
# Found heuristic solution: objective 10812.908134
#
# Root relaxation: objective 9.411398e+03, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9411.39763    0    8 10812.9081 9411.39763  13.0%     -    0s
# H    0     0                    10478.064297 9411.39763  10.2%     -    0s
#      0     0 9638.12834    0    9 10478.0643 9638.12834  8.02%     -    0s
# H    0     0                    9822.6607883 9638.12834  1.88%     -    0s
#      0     0 9660.47609    0    9 9822.66079 9660.47609  1.65%     -    0s
#      0     0 9685.18810    0    5 9822.66079 9685.18810  1.40%     -    0s
# H    0     0                    9817.8966507 9685.18810  1.35%     -    0s
#      0     0 9686.49765    0    5 9817.89665 9686.49765  1.34%     -    0s
#      0     0 9700.46514    0    7 9817.89665 9700.46514  1.20%     -    0s
#      0     0 9700.53907    0    7 9817.89665 9700.53907  1.20%     -    0s
#      0     0 9701.88317    0    7 9817.89665 9701.88317  1.18%     -    0s
#      0     0 9702.51273    0    8 9817.89665 9702.51273  1.18%     -    0s
#      0     0 9715.05063    0    5 9817.89665 9715.05063  1.05%     -    0s
# H    0     0                    9771.6642971 9715.05063  0.58%     -    0s
#      0     0 9715.82617    0    6 9771.66430 9715.82617  0.57%     -    0s
#      0     0 9717.64146    0    5 9771.66430 9717.64146  0.55%     -    0s
#      0     0 9717.68725    0    5 9771.66430 9717.68725  0.55%     -    0s
#      0     0 9718.49842    0    4 9771.66430 9718.49842  0.54%     -    0s
#      0     0 9718.52746    0    6 9771.66430 9718.52746  0.54%     -    0s
#      0     0 9718.53912    0    6 9771.66430 9718.53912  0.54%     -    0s
#      0     0 9718.61602    0    6 9771.66430 9718.61602  0.54%     -    0s
#      0     0 9718.61602    0    6 9771.66430 9718.61602  0.54%     -    0s
#      0     2 9719.45932    0    6 9771.66430 9719.45932  0.53%     -    0s
# H    9     0                    9734.5737070 9719.45932  0.16%   4.8    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 9
#   Flow cover: 12
#   Flow path: 4
#
# Explored 13 nodes (174 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 6: 9734.57 9771.66 9817.9 ... 10812.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.734573706995e+03, best bound 9.734573706995e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x68f1ebe4
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 213 rows and 232 columns
# Presolve time: 0.00s
# Presolved: 47 rows, 80 columns, 144 nonzeros
# Variable types: 72 continuous, 8 integer (8 binary)
# Found heuristic solution: objective 10704.600000
#
# Root relaxation: objective 9.643190e+03, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9643.19048    0    6 10704.6000 9643.19048  9.92%     -    0s
# H    0     0                    10542.000000 9643.19048  8.53%     -    0s
#      0     0 9782.18283    0    6 10542.0000 9782.18283  7.21%     -    0s
# H    0     0                    10520.226789 9782.18283  7.02%     -    0s
# H    0     0                    9936.2000000 9782.18283  1.55%     -    0s
#      0     0 9802.42830    0    6 9936.20000 9802.42830  1.35%     -    0s
# H    0     0                    9862.2000000 9802.42830  0.61%     -    0s
#      0     0 9806.82494    0    4 9862.20000 9806.82494  0.56%     -    0s
#      0     0 9806.85591    0    4 9862.20000 9806.85591  0.56%     -    0s
#      0     0 9817.01832    0    7 9862.20000 9817.01832  0.46%     -    0s
#      0     0 9827.39630    0    6 9862.20000 9827.39630  0.35%     -    0s
#      0     0 9836.87859    0    4 9862.20000 9836.87859  0.26%     -    0s
#      0     0 9837.52464    0    5 9862.20000 9837.52464  0.25%     -    0s
#      0     0 9840.79939    0    4 9862.20000 9840.79939  0.22%     -    0s
# H    0     0                    9841.6000000 9840.79939  0.01%     -    0s
#      0     0 9841.23238    0    1 9841.60000 9841.23238  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 4
#   Flow cover: 9
#   Flow path: 1
#
# Explored 1 nodes (74 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 6: 9841.6 9862.2 9936.2 ... 10704.6
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.841600000000e+03, best bound 9.841600000000e+03, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x6c05a525
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve removed 226 rows and 246 columns
# Presolve time: 0.00s
# Presolved: 34 rows, 66 columns, 112 nonzeros
# Variable types: 64 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 10035.200000
#
# Root relaxation: objective 9.840295e+03, 25 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9840.29524    0    1 10035.2000 9840.29524  1.94%     -    0s
# H    0     0                    9842.2000000 9840.29524  0.02%     -    0s
# *    0     0               0    9841.6000000 9841.60000  0.00%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 9841.6 10035.2
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.841600000000e+03, best bound 9.841600000000e+03, gap 0.0000%
