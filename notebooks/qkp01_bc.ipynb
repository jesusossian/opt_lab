# %% [markdown]
# # Mochila Quadrática $0$-$1$ (QKP)

# %% [markdown]
# ## Dados
#
# Considere dos seguintes dados:
#
# -  $N = \{1, \ldots, n\}$ um conjunto dos objetos.
#
# -  $P = \{p_{ij} \in \mathbb{R}_{+} : \ i \leq j, \ i, j \in N \}$ o conjunto dos benefícios aos itens de $N$ e a relação entre eles.
#
# -  $W = \{ w_i \in \mathbb{N} : i \in N \}$ o conjunto dos pesos dos itens de $N$.
#
# -  $c \in \mathbb{N}$ capacidade da mochila, onde $\displaystyle\max_{i \in N} w_i \leq c < \sum_{i  \in N} w_i$.

# %% [markdown]
# ## QKP 0-1 linear
#
# Utilizando os dados acima para definir o problema da mochila quadrática 0-1.
#
# \begin{align}
# max \; & \sum_{i \in N} q_{i} x_i + \sum_{i = 1}^{n-1} \sum_{j =i+1}^{n}
# p_{ij} y_{i,j} \\
# & \sum_{i \in N} w_{i} x_{i} \leq c, \\
# &  y_{i,j} \leq x_{i}, \\
# &  y_{i,j} \leq x_{j}, \\
# &  x_{i} + x_{j} \leq y_{i,j} + 1, \\
# & x_{i} \in \left\{0, 1 \right\}, \ \ i  \in N.
# \end{align}
#
# onde $q_{i} = p_{ii}, \ i \in N$.

# %% [markdown]
# **Callback:** função chamada periodicamente no meio da otimização, permitindo modificar e/ou monitorar o estado da otimização.
#
# **Argumentos da função de callback:**
#
# - modelo
#
# - **where**, indica onde a função de callback será chamada.
# Para utilizá-la é necessário adicionar GRB.Callback mais o código referente ao where desejado.
# É importante definir o que você quer fazer (what), para o termo what há um número muito grande de informações que podem ser obtidas que estão diretamente ligadas com o where utilizado.
# Para utilizá-la é necessário adicionar a função Model.cbGet( ) e como argumento dessa função passar o GRB.Callback mais o código referente a informação desejada.
#
# Callbacks are used to report on the progress of the optimization or to modify the behavior of the Gurobi solver.
#
# To use a callback, the user writes a routine that implements the desired behavior.
#
# The routine is passed to the Gurobi Optimizer when optimization begins, and the routine is called regularly during the optimization process.
#
# One argument of the user routine is a **where value**, which indicates from where in the optimization process the callback is invoked.
#
# The user callback routine can call the optimization library to query certain values.

# %% [markdown]
# ## Modelando o problema e resolvendo com gurobipy

# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB

# %%
def read_instance(dim,perc,t):

    instance = f"instances/{dim}/{dim}_{perc}_{t}.txt"

    with open(instance, 'r') as file: linhas = file.readlines()

    # remove linha vazia inicial e elimina os "\n" de cada linha
    linhas = [a.strip() for a in linhas] 

    # ler o tamanho da instancia
    n = int(linhas[0]) 

    # ler a diagonal da matriz
    d = np.fromstring(linhas[1], dtype=int, sep = ' ') 

    # define a matriz
    p = np.zeros((n,n), dtype=int) 

    # preenche a diagonal
    for i in range(n): 
        p[i][i] = d[i]

    # preenche o resto da matriz
    for i in range(n-1): 
        linha = np.fromstring(linhas[i+2], dtype=int, sep = ' ')
        for j in range(n-(i+1)):
            p[i][j+i+1] = linha[j]
            p[j+i+1][i] = p[i][j+i+1]

    # ler a capacidade
    c = int(linhas[n+2]) 

    # ler os pesos
    w = np.fromstring(linhas[n+3], dtype=int, sep = ' ') 

    return n, p, w, c

# %%
def bc_callback(model, where):
  
  if where == GRB.Callback.MIPNODE:

    x_var,y_var = model.__data
    n = len(x_var)
    
    # MIP node callback
    status = model.cbGet(GRB.Callback.MIPNODE_STATUS)
    
    print('**** New node ****')    
    
    if status == GRB.OPTIMAL:
      print("status = ", status)
      x = model.cbGetNodeRel(model._vars)
      model.cbSetSolution(model.getVars(), x)
      
      #print("tam x:", len(x))
      #print(x)
      
      #print("n = ", n)
      k = n-1          
      for i in range(0,n):
        for j in range(i+1, n):
          k = k + 1 
          #print("i %d, j %d , k %d " %(i,j,k))
          if (x[i] + x[j] > 1 + x[k]):
            print("corte adicionado: x[%d] + x[%d] <= 1 + y[%d,%d]" %(i,j,i,j))
            model.cbCut(model._vars[i] + model._vars[j] <= 1 + model._vars[k])

  #if where == GRB.Callback.MIPSOL:
  #  print("Time(s):",model.cbGet(GRB.Callback.RUNTIME),
  #  "best solution:",model.cbGet(GRB.Callback.MIPSOL_OBJBST),
  #  "best bound:",model.cbGet(GRB.Callback.MIPSOL_OBJBND))

# %%
def qknapsack(dim,perc,t):

    # read instance
    n, p, w, c = read_instance(dim, perc, t)

    #cria o modelo
    model = gp.Model("qkp_linear") 

    x = []
    for j in range(0, n):
        x.append(model.addVar(vtype=GRB.BINARY, name="x_{}".format(j+1)))

    l = list(tuple())
    for i in range(0, n):
        for j in range(i+1, n):
            l.append((i,j))

    y = model.addVars(l, vtype=GRB.BINARY, name='y') #Adicionando Variáveis 
        
    obj = 0 
    for i in range(0, n):
        obj += p[i][i] * x[i]
        for j in range(i+1, n):
            obj += p[i][j] * y[i,j]

    model.setObjective(obj, GRB.MAXIMIZE)

    constr = 0
    for j in range(0, n):
        constr += (w[j] * x[j])
    model.addConstr(constr <= c)

    for i in range(0,n):
        for j in range(i+1, n):
            constr1 = y[i,j]
            model.addConstr(constr1 <= x[i])

    for i in range(0,n):
        for j in range(i+1, n):
            constr2 = y[i,j]
            model.addConstr(constr2 <= x[j])

    #for i in range(0,n):
    #    for j in range(i+1, n):
    #        constr3 = x[i] + x[j]
    #        model.addConstr(constr3 <= 1 + y[i,j])
            
    model.__data = x,y

    model.write(f"lp/qkp_bc_linear_{dim}_{perc}_{t}.lp")

    # configurando parametros
    #model.Params.IterationLimit = 1000 # define o número de iterações do simplex
    #model.Params.TimeLimit = 60 # define tempo limite
    model.Params.MIPGap = 1.e-6 # define valor do gap
    #model.Params.method = 1
    #model.Params.NodeMethod = -1 #  -1=automatic, 0=primal simplex, 1=dual simplex, and 2=barrier
    model.Params.Threads = 1
    model.Params.Presolve = 0
    model.Params.Cuts = 0
    model.Params.PreCrush = 1
    
    # Turn off display
    gp.setParam('OutputFlag', 0)
    # Turn off heuristics
    #gp.setParam('Heuristics', 0)

    # Open log file
    logfile = open('bc_callback.log', 'w')
 
    # Pass data into my callback function
    model._lastiter = -GRB.INFINITY
    model._lastnode = -GRB.INFINITY
    model._logfile = logfile
    model._vars = model.getVars()

    model.optimize(bc_callback)

    #model.optimize()
    
    status = 0
    if model.status == GRB.OPTIMAL:
        status = 1
 
    ub = model.objBound
    lb = model.objVal
    gap = model.MIPGap
    time = model.Runtime
    nodes = model.NodeCount

    model.dispose()

    #lower bound, upper bound, gap, time, nodes
    arquivo = open(f'result/qkp_linear_{dim}_{perc}.csv','a')
    arquivo.write(
        str(f"{dim}_{perc}_{t}")+';'
        +str(round(lb,1))+';'
        +str(round(ub,1))+';'
        +str(round(gap,2))+';'
        +str(round(time,2))+';'
        +str(round(nodes,1))+';'
        +str(round(status,1))+'\n'
    )
    arquivo.close()

# %%
# __main__ : “top-level code environment”

# What is the “top-level code environment”?
# __main__ is the name of the environment where top-level code is run. 
# “Top-level code” is the first user-specified Python module that starts running. 
# It’s “top-level” because it imports all other modules that the program needs. 
# Sometimes “top-level code” is called an entry point to the application.

if __name__ == "__main__":

    for dim in [50]:
        for perc in [75]:
            for t in range(1,2):
                instance = f"instances/{dim}/{dim}_{perc}_{t}.txt"
                qknapsack(dim,perc,t)
# Out:
# **** New node ****
# status =  2
# corte adicionado: x[0] + x[6] <= 1 + y[0,6]
# corte adicionado: x[0] + x[9] <= 1 + y[0,9]
# corte adicionado: x[0] + x[25] <= 1 + y[0,25]
# corte adicionado: x[0] + x[26] <= 1 + y[0,26]
# corte adicionado: x[0] + x[36] <= 1 + y[0,36]
# corte adicionado: x[1] + x[6] <= 1 + y[1,6]
# corte adicionado: x[1] + x[8] <= 1 + y[1,8]
# corte adicionado: x[1] + x[11] <= 1 + y[1,11]
# corte adicionado: x[1] + x[19] <= 1 + y[1,19]
# corte adicionado: x[1] + x[33] <= 1 + y[1,33]
# corte adicionado: x[1] + x[36] <= 1 + y[1,36]
# corte adicionado: x[1] + x[43] <= 1 + y[1,43]
# corte adicionado: x[2] + x[4] <= 1 + y[2,4]
# corte adicionado: x[2] + x[14] <= 1 + y[2,14]
# corte adicionado: x[2] + x[17] <= 1 + y[2,17]
# corte adicionado: x[2] + x[19] <= 1 + y[2,19]
# corte adicionado: x[2] + x[25] <= 1 + y[2,25]
# corte adicionado: x[2] + x[28] <= 1 + y[2,28]
# corte adicionado: x[2] + x[29] <= 1 + y[2,29]
# corte adicionado: x[2] + x[42] <= 1 + y[2,42]
# corte adicionado: x[2] + x[43] <= 1 + y[2,43]
# corte adicionado: x[2] + x[44] <= 1 + y[2,44]
# corte adicionado: x[2] + x[45] <= 1 + y[2,45]
# corte adicionado: x[2] + x[48] <= 1 + y[2,48]
# corte adicionado: x[3] + x[7] <= 1 + y[3,7]
# corte adicionado: x[3] + x[8] <= 1 + y[3,8]
# corte adicionado: x[3] + x[15] <= 1 + y[3,15]
# corte adicionado: x[3] + x[17] <= 1 + y[3,17]
# corte adicionado: x[3] + x[18] <= 1 + y[3,18]
# corte adicionado: x[3] + x[24] <= 1 + y[3,24]
# corte adicionado: x[3] + x[30] <= 1 + y[3,30]
# corte adicionado: x[3] + x[40] <= 1 + y[3,40]
# corte adicionado: x[3] + x[47] <= 1 + y[3,47]
# corte adicionado: x[4] + x[8] <= 1 + y[4,8]
# corte adicionado: x[4] + x[10] <= 1 + y[4,10]
# corte adicionado: x[4] + x[13] <= 1 + y[4,13]
# corte adicionado: x[4] + x[25] <= 1 + y[4,25]
# corte adicionado: x[4] + x[26] <= 1 + y[4,26]
# corte adicionado: x[27] + x[36] <= 1 + y[27,36]
# corte adicionado: x[29] + x[31] <= 1 + y[29,31]
# corte adicionado: x[29] + x[37] <= 1 + y[29,37]
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# corte adicionado: x[32] + x[37] <= 1 + y[32,37]
# corte adicionado: x[32] + x[38] <= 1 + y[32,38]
# corte adicionado: x[32] + x[49] <= 1 + y[32,49]
# corte adicionado: x[37] + x[40] <= 1 + y[37,40]
# corte adicionado: x[37] + x[42] <= 1 + y[37,42]
# corte adicionado: x[37] + x[43] <= 1 + y[37,43]
# corte adicionado: x[37] + x[47] <= 1 + y[37,47]
# corte adicionado: x[38] + x[42] <= 1 + y[38,42]
# corte adicionado: x[41] + x[42] <= 1 + y[41,42]
# corte adicionado: x[47] + x[49] <= 1 + y[47,49]
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# corte adicionado: x[0] + x[14] <= 1 + y[0,14]
# corte adicionado: x[0] + x[15] <= 1 + y[0,15]
# corte adicionado: x[0] + x[17] <= 1 + y[0,17]
# corte adicionado: x[0] + x[23] <= 1 + y[0,23]
# corte adicionado: x[0] + x[30] <= 1 + y[0,30]
# corte adicionado: x[0] + x[31] <= 1 + y[0,31]
# corte adicionado: x[0] + x[32] <= 1 + y[0,32]
# corte adicionado: x[0] + x[42] <= 1 + y[0,42]
# corte adicionado: x[1] + x[14] <= 1 + y[1,14]
# corte adicionado: x[1] + x[15] <= 1 + y[1,15]
# corte adicionado: x[1] + x[17] <= 1 + y[1,17]
# corte adicionado: x[1] + x[23] <= 1 + y[1,23]
# corte adicionado: x[1] + x[30] <= 1 + y[1,30]
# corte adicionado: x[1] + x[31] <= 1 + y[1,31]
# corte adicionado: x[1] + x[32] <= 1 + y[1,32]
# corte adicionado: x[1] + x[42] <= 1 + y[1,42]
# corte adicionado: x[4] + x[14] <= 1 + y[4,14]
# corte adicionado: x[4] + x[15] <= 1 + y[4,15]
# corte adicionado: x[4] + x[17] <= 1 + y[4,17]
# corte adicionado: x[4] + x[30] <= 1 + y[4,30]
# corte adicionado: x[4] + x[31] <= 1 + y[4,31]
# corte adicionado: x[4] + x[32] <= 1 + y[4,32]
# corte adicionado: x[5] + x[15] <= 1 + y[5,15]
# corte adicionado: x[5] + x[17] <= 1 + y[5,17]
# corte adicionado: x[7] + x[14] <= 1 + y[7,14]
# corte adicionado: x[7] + x[15] <= 1 + y[7,15]
# corte adicionado: x[7] + x[17] <= 1 + y[7,17]
# corte adicionado: x[7] + x[23] <= 1 + y[7,23]
# corte adicionado: x[7] + x[30] <= 1 + y[7,30]
# corte adicionado: x[7] + x[31] <= 1 + y[7,31]
# corte adicionado: x[7] + x[32] <= 1 + y[7,32]
# corte adicionado: x[7] + x[42] <= 1 + y[7,42]
# corte adicionado: x[14] + x[15] <= 1 + y[14,15]
# corte adicionado: x[14] + x[17] <= 1 + y[14,17]
# corte adicionado: x[14] + x[20] <= 1 + y[14,20]
# corte adicionado: x[14] + x[21] <= 1 + y[14,21]
# corte adicionado: x[14] + x[23] <= 1 + y[14,23]
# corte adicionado: x[14] + x[27] <= 1 + y[14,27]
# corte adicionado: x[14] + x[28] <= 1 + y[14,28]
# corte adicionado: x[14] + x[30] <= 1 + y[14,30]
# corte adicionado: x[14] + x[31] <= 1 + y[14,31]
# corte adicionado: x[14] + x[32] <= 1 + y[14,32]
# corte adicionado: x[14] + x[35] <= 1 + y[14,35]
# corte adicionado: x[14] + x[37] <= 1 + y[14,37]
# corte adicionado: x[14] + x[38] <= 1 + y[14,38]
# corte adicionado: x[14] + x[42] <= 1 + y[14,42]
# corte adicionado: x[14] + x[46] <= 1 + y[14,46]
# corte adicionado: x[14] + x[49] <= 1 + y[14,49]
# corte adicionado: x[15] + x[17] <= 1 + y[15,17]
# corte adicionado: x[15] + x[20] <= 1 + y[15,20]
# corte adicionado: x[15] + x[21] <= 1 + y[15,21]
# corte adicionado: x[15] + x[23] <= 1 + y[15,23]
# corte adicionado: x[15] + x[27] <= 1 + y[15,27]
# corte adicionado: x[15] + x[28] <= 1 + y[15,28]
# corte adicionado: x[15] + x[30] <= 1 + y[15,30]
# corte adicionado: x[15] + x[31] <= 1 + y[15,31]
# corte adicionado: x[15] + x[32] <= 1 + y[15,32]
# corte adicionado: x[15] + x[35] <= 1 + y[15,35]
# corte adicionado: x[15] + x[37] <= 1 + y[15,37]
# corte adicionado: x[15] + x[38] <= 1 + y[15,38]
# corte adicionado: x[15] + x[42] <= 1 + y[15,42]
# corte adicionado: x[15] + x[46] <= 1 + y[15,46]
# corte adicionado: x[15] + x[47] <= 1 + y[15,47]
# corte adicionado: x[15] + x[49] <= 1 + y[15,49]
# corte adicionado: x[17] + x[20] <= 1 + y[17,20]
# corte adicionado: x[17] + x[21] <= 1 + y[17,21]
# corte adicionado: x[17] + x[23] <= 1 + y[17,23]
# corte adicionado: x[17] + x[27] <= 1 + y[17,27]
# corte adicionado: x[17] + x[28] <= 1 + y[17,28]
# corte adicionado: x[17] + x[30] <= 1 + y[17,30]
# corte adicionado: x[17] + x[31] <= 1 + y[17,31]
# corte adicionado: x[17] + x[32] <= 1 + y[17,32]
# corte adicionado: x[17] + x[35] <= 1 + y[17,35]
# corte adicionado: x[17] + x[37] <= 1 + y[17,37]
# corte adicionado: x[17] + x[38] <= 1 + y[17,38]
# corte adicionado: x[17] + x[42] <= 1 + y[17,42]
# corte adicionado: x[17] + x[46] <= 1 + y[17,46]
# corte adicionado: x[17] + x[47] <= 1 + y[17,47]
# corte adicionado: x[17] + x[49] <= 1 + y[17,49]
# corte adicionado: x[20] + x[23] <= 1 + y[20,23]
# corte adicionado: x[20] + x[30] <= 1 + y[20,30]
# corte adicionado: x[20] + x[31] <= 1 + y[20,31]
# corte adicionado: x[20] + x[32] <= 1 + y[20,32]
# corte adicionado: x[20] + x[42] <= 1 + y[20,42]
# corte adicionado: x[21] + x[23] <= 1 + y[21,23]
# corte adicionado: x[21] + x[30] <= 1 + y[21,30]
# corte adicionado: x[21] + x[31] <= 1 + y[21,31]
# corte adicionado: x[21] + x[32] <= 1 + y[21,32]
# corte adicionado: x[21] + x[42] <= 1 + y[21,42]
# corte adicionado: x[23] + x[27] <= 1 + y[23,27]
# corte adicionado: x[4] + x[42] <= 1 + y[4,42]
# corte adicionado: x[14] + x[37] <= 1 + y[14,37]
# corte adicionado: x[15] + x[30] <= 1 + y[15,30]
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# corte adicionado: x[37] + x[42] <= 1 + y[37,42]
# corte adicionado: x[47] + x[49] <= 1 + y[47,49]
# **** New node ****
# **** New node ****
# status =  2
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# corte adicionado: x[47] + x[49] <= 1 + y[47,49]
# **** New node ****
# status =  2
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# corte adicionado: x[47] + x[49] <= 1 + y[47,49]
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# corte adicionado: x[4] + x[5] <= 1 + y[4,5]
# corte adicionado: x[5] + x[8] <= 1 + y[5,8]
# corte adicionado: x[5] + x[9] <= 1 + y[5,9]
# corte adicionado: x[5] + x[12] <= 1 + y[5,12]
# corte adicionado: x[5] + x[22] <= 1 + y[5,22]
# corte adicionado: x[5] + x[26] <= 1 + y[5,26]
# corte adicionado: x[5] + x[32] <= 1 + y[5,32]
# corte adicionado: x[14] + x[23] <= 1 + y[14,23]
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# corte adicionado: x[4] + x[5] <= 1 + y[4,5]
# corte adicionado: x[4] + x[23] <= 1 + y[4,23]
# corte adicionado: x[4] + x[37] <= 1 + y[4,37]
# corte adicionado: x[4] + x[42] <= 1 + y[4,42]
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# **** New node ****
# status =  2
# corte adicionado: x[30] + x[32] <= 1 + y[30,32]
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# corte adicionado: x[0] + x[5] <= 1 + y[0,5]
# corte adicionado: x[0] + x[14] <= 1 + y[0,14]
# corte adicionado: x[0] + x[23] <= 1 + y[0,23]
# corte adicionado: x[0] + x[30] <= 1 + y[0,30]
# corte adicionado: x[0] + x[31] <= 1 + y[0,31]
# corte adicionado: x[0] + x[42] <= 1 + y[0,42]
# corte adicionado: x[1] + x[5] <= 1 + y[1,5]
# corte adicionado: x[1] + x[14] <= 1 + y[1,14]
# corte adicionado: x[1] + x[23] <= 1 + y[1,23]
# corte adicionado: x[1] + x[30] <= 1 + y[1,30]
# corte adicionado: x[1] + x[31] <= 1 + y[1,31]
# corte adicionado: x[1] + x[42] <= 1 + y[1,42]
# corte adicionado: x[2] + x[4] <= 1 + y[2,4]
# corte adicionado: x[4] + x[8] <= 1 + y[4,8]
# corte adicionado: x[4] + x[10] <= 1 + y[4,10]
# corte adicionado: x[4] + x[13] <= 1 + y[4,13]
# corte adicionado: x[4] + x[14] <= 1 + y[4,14]
# corte adicionado: x[4] + x[25] <= 1 + y[4,25]
# corte adicionado: x[4] + x[26] <= 1 + y[4,26]
# corte adicionado: x[4] + x[30] <= 1 + y[4,30]
# corte adicionado: x[4] + x[31] <= 1 + y[4,31]
# corte adicionado: x[4] + x[34] <= 1 + y[4,34]
# corte adicionado: x[4] + x[48] <= 1 + y[4,48]
# corte adicionado: x[5] + x[7] <= 1 + y[5,7]
# corte adicionado: x[5] + x[14] <= 1 + y[5,14]
# corte adicionado: x[5] + x[20] <= 1 + y[5,20]
# corte adicionado: x[5] + x[21] <= 1 + y[5,21]
# corte adicionado: x[5] + x[23] <= 1 + y[5,23]
# corte adicionado: x[5] + x[27] <= 1 + y[5,27]
# corte adicionado: x[5] + x[28] <= 1 + y[5,28]
# corte adicionado: x[5] + x[29] <= 1 + y[5,29]
# corte adicionado: x[5] + x[30] <= 1 + y[5,30]
# corte adicionado: x[5] + x[31] <= 1 + y[5,31]
# corte adicionado: x[5] + x[35] <= 1 + y[5,35]
# corte adicionado: x[5] + x[37] <= 1 + y[5,37]
# corte adicionado: x[5] + x[38] <= 1 + y[5,38]
# corte adicionado: x[5] + x[40] <= 1 + y[5,40]
# corte adicionado: x[5] + x[42] <= 1 + y[5,42]
# corte adicionado: x[5] + x[46] <= 1 + y[5,46]
# corte adicionado: x[5] + x[49] <= 1 + y[5,49]
# corte adicionado: x[7] + x[14] <= 1 + y[7,14]
# corte adicionado: x[7] + x[23] <= 1 + y[7,23]
# corte adicionado: x[7] + x[30] <= 1 + y[7,30]
# corte adicionado: x[7] + x[31] <= 1 + y[7,31]
# corte adicionado: x[7] + x[42] <= 1 + y[7,42]
# corte adicionado: x[11] + x[37] <= 1 + y[11,37]
# corte adicionado: x[12] + x[49] <= 1 + y[12,49]
# corte adicionado: x[13] + x[37] <= 1 + y[13,37]
# corte adicionado: x[14] + x[20] <= 1 + y[14,20]
# corte adicionado: x[14] + x[21] <= 1 + y[14,21]
# corte adicionado: x[14] + x[23] <= 1 + y[14,23]
# corte adicionado: x[14] + x[27] <= 1 + y[14,27]
# corte adicionado: x[14] + x[28] <= 1 + y[14,28]
# corte adicionado: x[14] + x[29] <= 1 + y[14,29]
# corte adicionado: x[14] + x[30] <= 1 + y[14,30]
# corte adicionado: x[14] + x[31] <= 1 + y[14,31]
# corte adicionado: x[14] + x[35] <= 1 + y[14,35]
# corte adicionado: x[14] + x[38] <= 1 + y[14,38]
# corte adicionado: x[14] + x[40] <= 1 + y[14,40]
# corte adicionado: x[14] + x[42] <= 1 + y[14,42]
# corte adicionado: x[14] + x[46] <= 1 + y[14,46]
# corte adicionado: x[14] + x[49] <= 1 + y[14,49]
# corte adicionado: x[18] + x[37] <= 1 + y[18,37]
# corte adicionado: x[18] + x[49] <= 1 + y[18,49]
# corte adicionado: x[20] + x[23] <= 1 + y[20,23]
# corte adicionado: x[20] + x[30] <= 1 + y[20,30]
# corte adicionado: x[20] + x[31] <= 1 + y[20,31]
# corte adicionado: x[20] + x[42] <= 1 + y[20,42]
# corte adicionado: x[21] + x[23] <= 1 + y[21,23]
# corte adicionado: x[21] + x[30] <= 1 + y[21,30]
# corte adicionado: x[21] + x[31] <= 1 + y[21,31]
# corte adicionado: x[21] + x[42] <= 1 + y[21,42]
# corte adicionado: x[23] + x[27] <= 1 + y[23,27]
# corte adicionado: x[23] + x[28] <= 1 + y[23,28]
# corte adicionado: x[23] + x[29] <= 1 + y[23,29]
# corte adicionado: x[23] + x[30] <= 1 + y[23,30]
# corte adicionado: x[23] + x[31] <= 1 + y[23,31]
# corte adicionado: x[23] + x[35] <= 1 + y[23,35]
# corte adicionado: x[23] + x[37] <= 1 + y[23,37]
# corte adicionado: x[7] + x[25] <= 1 + y[7,25]
# corte adicionado: x[14] + x[25] <= 1 + y[14,25]
# corte adicionado: x[15] + x[25] <= 1 + y[15,25]
# corte adicionado: x[17] + x[25] <= 1 + y[17,25]
# corte adicionado: x[20] + x[25] <= 1 + y[20,25]
# corte adicionado: x[21] + x[25] <= 1 + y[21,25]
# corte adicionado: x[22] + x[25] <= 1 + y[22,25]
# corte adicionado: x[23] + x[25] <= 1 + y[23,25]
# corte adicionado: x[25] + x[27] <= 1 + y[25,27]
# corte adicionado: x[25] + x[28] <= 1 + y[25,28]
# corte adicionado: x[25] + x[29] <= 1 + y[25,29]
# corte adicionado: x[25] + x[31] <= 1 + y[25,31]
# corte adicionado: x[25] + x[35] <= 1 + y[25,35]
# corte adicionado: x[25] + x[36] <= 1 + y[25,36]
# corte adicionado: x[25] + x[38] <= 1 + y[25,38]
# corte adicionado: x[25] + x[40] <= 1 + y[25,40]
# corte adicionado: x[25] + x[42] <= 1 + y[25,42]
# corte adicionado: x[25] + x[46] <= 1 + y[25,46]
# corte adicionado: x[25] + x[47] <= 1 + y[25,47]
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# **** New node ****
# status =  2
# **** New node ****
# **** New node ****

# %% [markdown]
# ## Tabelando os resultados

# %%
import pandas as pd

dim = 50
perc = 75
inst_=f'result/qkp_linear_{dim}_{perc}.txt'

df = pd.DataFrame()
df = pd.read_csv(inst_,header=None,sep=';')

tab = pd.DataFrame()
tab = pd.concat([tab, df], ignore_index=True)
tab.columns = ['instance','bs','bb','gap','time','nodes','opt']

resume = pd.DataFrame({
    'instance':f"resume",
    'bs':tab["bs"].mean(),
    'bb':tab["bb"].mean(),
    'gap':tab['gap'].mean(),
    'time':tab['time'].mean(),
    'nodes':tab['nodes'].mean(),
    'opt':tab['opt'].sum(),
     },index=[f"qkp"]
)

tab = pd.concat([tab, resume], ignore_index=True)

tab["bb"] = tab["bb"].round(2)
tab["bs"] = tab["bs"].round(2)
tab["gap"] = tab["gap"].round(2)
tab["time"] = tab["time"].round(2)
tab["nodes"] = tab["nodes"].round(2)
tab["opt"] = tab["opt"].round().astype('Int64')

tab
# Out:
#     instance       bs       bb  gap  time  nodes  opt
# 0    50_75_1  14162.0  14162.0  0.0  0.77   27.0    1
# 1    50_75_2  12226.0  12226.0  0.0  0.76   64.0    1
# 2    50_75_3  23254.0  23254.0  0.0  0.05    1.0    1
# 3    50_75_4   2314.0   2314.0  0.0  0.45   28.0    1
# 4    50_75_5  22157.0  22157.0  0.0  0.05    1.0    1
# 5    50_75_6  10411.0  10411.0  0.0  0.36    1.0    1
# 6    50_75_7  21583.0  21583.0  0.0  0.07    1.0    1
# 7    50_75_8   3820.0   3820.0  0.0  0.08    1.0    1
# 8    50_75_9  22051.0  22051.0  0.0  3.80  358.0    1
# 9   50_75_10  10461.0  10461.0  0.0  0.73   53.0    1
# 10    resume  14243.9  14243.9  0.0  0.71   53.5   10

# %%
print(
    tab[['instance','bs','bb','gap','time','nodes','opt']].
    to_latex(index=False,float_format="%.2f")
)
